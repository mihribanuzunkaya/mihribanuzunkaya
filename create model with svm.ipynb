# %% [markdown]
# # STEP 1 : IMPORT LIBRARIES

# %%
import pandas as pd # Import Pandas for data manipulation using dataframes
import numpy as np # Import Numpy for data statistical analysis 
import matplotlib.pyplot as plt # Import matplotlib for data visualisation
import seaborn as sns # Statistical data visualization
# %matplotlib inline

# %% [markdown]
# # STEP 2 : IMPORT DATA

# %%
training_set = pd.read_csv(r"C:\Users\Mihriban\Desktop\notebook\ActionFaceBody_AFB_.csv")

# %%
training_set.head(5)
# Out:
#   Participant  A11    A12  A13    A14  A15    A16  A17   A18   A19  ...  B22  \
# 0      child1   11  59920    1  14344   12  52438    6  8229  7347  ...  144
# 1      child2   11  59920    1  14344   12  43562    6  5546  5346  ...  234
# 2      child3   11  59920    1  14344   12  64463    8  2495  2399  ...  384
# 3      child4   11  59920    1  14344   12  19404    2  1259  1099  ...  308
# 4      child5   11  59920    1  14344   12  60397    8  5762  5444  ...  286
#
#    B23  B24  B25  B26  B27   B28  B29  B30  Class
# 0    1    0    2    0    0   291    0  150    OSB
# 1    1    0    1    0    0   393    0  253     NG
# 2    2    2    4    1    1  1561    1  381    OSB
# 3    2    1    3    2    1  1706    1  452    OSB
# 4    3    2    4    1    1  1611    1  419    OSB
#
# [5 rows x 62 columns]

# %% [markdown]
# # STEP 2 : EXPLORE/VISUALIZE DATASET

# %%
# number of ASDs and TDs
NG = training_set[training_set['Class'] == 'OSB']
OSB = training_set [training_set['Class']== 'NG']

# %%
print ('Total= ', len(training_set))
print ('Number of child who OSB =', len(OSB) )
print ('Number of child who NG =', len(NG))
# Out:
# Total=  119
# Number of child who OSB = 63
# Number of child who NG = 56

# %%
print('OSB = %' , 1. * len(OSB)/len(training_set) * 100)
print('NG = %' , 1. * len(NG)/len(training_set) * 100)
# Out:
# OSB = % 52.94117647058824
# NG = % 47.05882352941176

# %%
OSB = training_set[training_set['Class'] == 'OSB']

# %%
OSB
# Out:
#     Participant  A11    A12  A13    A14  A15    A16  A17   A18   A19  ...  \
# 0        child1   11  59920    1  14344   12  52438    6  8229  7347  ...
# 2        child3   11  59920    1  14344   12  64463    8  2495  2399  ...
# 3        child4   11  59920    1  14344   12  19404    2  1259  1099  ...
# 4        child5   11  59920    1  14344   12  60397    8  5762  5444  ...
# 5        child6   11  59920    1  14344   12  38512    2   299   274  ...
# 7        child8   11  59920    1  14344   12  61302    7  2292  2173  ...
# 8        child9   11  59920    1  14344   12  61695    8  8316  8228  ...
# 10      child11   11  59920    1  14344   12  52242    7  6818  6113  ...
# 11      child12   11  59920    1  14344   12  53236    7  2987  2859  ...
# 12      child13   11  59920    1  14344   12  51796    7  6681  6654  ...
# 13      child14   11  59920    1  14344   12  52091    7  4334  4292  ...
# 14      child15   11  59920    1  14344   12  60203    7  6564  6478  ...
# ...

# %%
NG = training_set [training_set['Class']== 'NG']

# %%
NG
# Out:
#     Participant  A11    A12  A13    A14  A15    A16  A17   A18   A19  ...  \
# 1        child2   11  59920    1  14344   12  43562    6  5546  5346  ...
# 6        child7   11  59920    1  14344   12  61277    7  3464  3240  ...
# 9       child10   11  59920    1  14344   12  45347    4  3890  3660  ...
# 15      child16   11  59920    1  14344   12  61917   10  6568  6430  ...
# 16      child17   11  59920    1  14344   12  52589    8  5482  5438  ...
# ..          ...  ...    ...  ...    ...  ...    ...  ...   ...   ...  ...
# 111    child112   11  59920    1  14344   12  61073    8  8366  8442  ...
# 112    child113   11  59920    1  14344   12  44297    7  2410  2476  ...
# 115    child116   11  59920    1  14344   12  43178    7  4928  4517  ...
# 117    child118   11  59920    1  14344   12  51922    6  3847  3395  ...
# 118    child119   11  59920    1  14344   12  43131    6  5930  5846  ...
#
#      B22  B23  B24  B25  B26  B27   B28  B29  B30  Class
# ...

# %%
sns.countplot(training_set['Class'], label='Count OSB vs NG')
# Out:
# C:\Users\Mihriban\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
#plt.figure (figsize = [30,40])
#plt.subplot (211)
#sns.countplot(x= 'Anim Glances Count', data=training_set)
#plt.subplot (212)
#sns.countplot(x= 'Anim Glances Count', hue= 'Class' , data=training_set)

# %%
#plt.figure (figsize = [30,40])
#plt.subplot (211)
#sns.countplot(x= 'SI Glances Count', data=training_set)
#plt.subplot (212)
#sns.countplot(x= 'SI Glances Count', hue= 'Class' , data=training_set)

# %% [markdown]
# # STEP 3 : PREPARE DATA FOR TRAINING/CLEANING

# %%
training_set
# Out:
#     Participant  A11    A12  A13    A14  A15    A16  A17   A18   A19  ...  \
# 0        child1   11  59920    1  14344   12  52438    6  8229  7347  ...
# 1        child2   11  59920    1  14344   12  43562    6  5546  5346  ...
# 2        child3   11  59920    1  14344   12  64463    8  2495  2399  ...
# 3        child4   11  59920    1  14344   12  19404    2  1259  1099  ...
# 4        child5   11  59920    1  14344   12  60397    8  5762  5444  ...
# ..          ...  ...    ...  ...    ...  ...    ...  ...   ...   ...  ...
# 114    child115   11  59920    1  14344   12  17799    1   197   185  ...
# 115    child116   11  59920    1  14344   12  43178    7  4928  4517  ...
# 116    child117   11  59920    1  14344   12  62454    9  3810  3224  ...
# 117    child118   11  59920    1  14344   12  51922    6  3847  3395  ...
# 118    child119   11  59920    1  14344   12  43131    6  5930  5846  ...
#
#      B22  B23  B24  B25  B26  B27   B28  B29  B30  Class
# ...

# %%
training_set.drop(['Participant','A11', 'A12', 'A13', 'A14', 'A15', 'F11', 'F12', 'F13', 'F14', 'F15', 'B11', 'B12', 'B13','B14', 'B15'], axis=1, inplace= True)

# %%
training_set
# Out:
#        A16  A17   A18   A19   A20   A21  A22  A23  A24  A25  ...  B22  B23  \
# 0    52438    6  8229  7347  7578  7710  149    3    2   22  ...  144    1
# 1    43562    6  5546  5346  5514  5700  376    4    3   10  ...  234    1
# 2    64463    8  2495  2399  2461  2538  244    2    1    5  ...  384    2
# 3    19404    2  1259  1099  1171  1223  264    1    1    2  ...  308    2
# 4    60397    8  5762  5444  5602  5749  307    4    3   11  ...  286    3
# ..     ...  ...   ...   ...   ...   ...  ...  ...  ...  ...  ...  ...  ...
# 114  17799    1   197   185   195   214   62    0    0    1  ...  335    3
# 115  43178    7  4928  4517  4684  4828  327    3    2   11  ...  410    2
# 116  62454    9  3810  3224  3404  3546  327    4    3    8  ...  180    1
# 117  51922    6  3847  3395  3587  3768  225    3    3    8  ...  204    3
# 118  43131    6  5930  5846  5957  6072  604    2    2    6  ...  471    2
#
#      B24  B25  B26  B27   B28  B29  B30  Class
# ...

# %%
sns.heatmap(training_set.isnull(), yticklabels = False, cbar = False , cmap = 'Blues' )
# Out:
# <AxesSubplot:>

# %%
training_set.describe()
# Out:
#                 A16         A17          A18          A19          A20  \
# count    119.000000  119.000000   119.000000   119.000000   119.000000
# mean   50438.462185    6.789916  4642.840336  4557.789916  4696.773109
# std    12413.098092    2.201209  2117.215324  2115.271485  2131.313085
# min     4661.000000    1.000000   197.000000   185.000000   195.000000
# 25%    43274.000000    6.000000  3154.000000  3199.000000  3330.000000
# 50%    52589.000000    7.000000  4696.000000  4643.000000  4779.000000
# 75%    61169.000000    8.000000  6275.500000  6127.000000  6261.500000
# max    66315.000000   11.000000  9263.000000  9319.000000  9423.000000
#
#                A21          A22         A23         A24         A25  ...  \
# count   119.000000   119.000000  119.000000  119.000000  119.000000  ...
# mean   4819.336134   404.462185    2.714286    1.882353    8.588235  ...
# std    2151.746564   262.771435    0.957954    0.912962    4.111604  ...
# ...

# %%
training_set
# Out:
#        A16  A17   A18   A19   A20   A21  A22  A23  A24  A25  ...  B22  B23  \
# 0    52438    6  8229  7347  7578  7710  149    3    2   22  ...  144    1
# 1    43562    6  5546  5346  5514  5700  376    4    3   10  ...  234    1
# 2    64463    8  2495  2399  2461  2538  244    2    1    5  ...  384    2
# 3    19404    2  1259  1099  1171  1223  264    1    1    2  ...  308    2
# 4    60397    8  5762  5444  5602  5749  307    4    3   11  ...  286    3
# ..     ...  ...   ...   ...   ...   ...  ...  ...  ...  ...  ...  ...  ...
# 114  17799    1   197   185   195   214   62    0    0    1  ...  335    3
# 115  43178    7  4928  4517  4684  4828  327    3    2   11  ...  410    2
# 116  62454    9  3810  3224  3404  3546  327    4    3    8  ...  180    1
# 117  51922    6  3847  3395  3587  3768  225    3    3    8  ...  204    3
# 118  43131    6  5930  5846  5957  6072  604    2    2    6  ...  471    2
#
#      B24  B25  B26  B27   B28  B29  B30  Class
# ...

# %% [markdown]
# # STEP 4 : VISUALIZING THE DATA

# %%
#sns.pairplot(training_set, hue = 'Class', vars= ['Anim Average Fixation Duration [ms]', 'SI Average Fixation Duration [ms]', 'Anim Fixation Time [ms]' , 'SI Fixation Time [ms]'])

# %%
#sns.countplot(training_set['TD'], label='count')

# %%
#sns.scatterplot(x='Toys Average Fixation Duration [ms]', y='SI Average Fixation Duration [ms]', hue='TD', data=training_set)

# %%
#sns.scatterplot(x='Toys Fixation Time [ms]', y='Toys Net Dwell Time [ms]', hue='TD', data=training_set)

# %%
#plt.figure(figsize = (20,10))
#sns.heatmap(training_set.corr(), annot= True)

# %% [markdown]
# # STEP 4 : MODEL TRAINING

# %%
X = training_set.drop(['Class'], axis=1)

# %%
X
# Out:
#        A16  A17   A18   A19   A20   A21  A22  A23  A24  A25  ...   B21  B22  \
# 0    52438    6  8229  7347  7578  7710  149    3    2   22  ...   453  144
# 1    43562    6  5546  5346  5514  5700  376    4    3   10  ...   500  234
# 2    64463    8  2495  2399  2461  2538  244    2    1    5  ...  1840  384
# 3    19404    2  1259  1099  1171  1223  264    1    1    2  ...  1859  308
# 4    60397    8  5762  5444  5602  5749  307    4    3   11  ...  1835  286
# ..     ...  ...   ...   ...   ...   ...  ...  ...  ...  ...  ...   ...  ...
# 114  17799    1   197   185   195   214   62    0    0    1  ...  2114  335
# 115  43178    7  4928  4517  4684  4828  327    3    2   11  ...  1371  410
# 116  62454    9  3810  3224  3404  3546  327    4    3    8  ...   469  180
# 117  51922    6  3847  3395  3587  3768  225    3    3    8  ...  1699  204
# 118  43131    6  5930  5846  5957  6072  604    2    2    6  ...  1385  471
#
#      B23  B24  B25  B26  B27   B28  B29  B30
# ...

# %%
y = training_set['Class']

# %%
y
# Out:
# 0      OSB
# 1       NG
# 2      OSB
# 3      OSB
# 4      OSB
#       ...
# 114    OSB
# 115     NG
# 116    OSB
# 117     NG
# 118     NG
# Name: Class, Length: 119, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.3)

# %%
X_train.shape # %80 data for trainig
# Out:
# (83, 45)

# %%
X_test.shape# %20 data for testing
# Out:
# (36, 45)

# %%
y_train.shape
# Out:
# (83,)

# %%
y_test.shape
# Out:
# (36,)

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report , confusion_matrix

# %%
svc_model = SVC ()

# %%
svc_model.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# # STEP 5 : EVALUATING THE MODEL

# %%
y_predict = svc_model.predict(X_test)

# %%
y_predict
# Out:
# array(['OSB', 'OSB', 'OSB', 'OSB', 'OSB', 'NG', 'NG', 'OSB', 'OSB', 'NG',
#        'OSB', 'OSB', 'NG', 'NG', 'OSB', 'NG', 'OSB', 'NG', 'OSB', 'NG',
#        'OSB', 'NG', 'OSB', 'OSB', 'NG', 'OSB', 'OSB', 'NG', 'OSB', 'OSB',
#        'NG', 'NG', 'NG', 'NG', 'NG', 'NG'], dtype=object)

# %%
cm = confusion_matrix(y_test, y_predict)

# %%
sns.heatmap(cm, annot = True)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#           NG       0.76      0.72      0.74        18
#          OSB       0.74      0.78      0.76        18
#
#     accuracy                           0.75        36
#    macro avg       0.75      0.75      0.75        36
# weighted avg       0.75      0.75      0.75        36

# %% [markdown]
# # STEP : 6 IMPROVING THE MODEL

# %%
min_train=X_train.min()

# %%
min_train
# Out:
# A16    4661
# A17       1
# A18     197
# A19     185
# A20     195
# A21     214
# A22      45
# A23       0
# A24       0
# A25       1
# A26       0
# A27       0
# A28     181
# A29       0
# A30      60
# F16     968
# F17       0
# F18      19
# F19      12
# F20      14
# F21      20
# F22       8
# F23       0
# F24       0
# F25       0
# F26       0
# F27       0
# F28      12
# F29       0
# F30       8
# B16    6870
# B17       2
# B18     144
# B19     112
# B20     126
# B21     139
# B22      54
# B23       0
# B24       0
# B25       0
# B26       0
# B27       0
# B28     112
# B29       0
# B30      60
# dtype: int64

# %%
range_train = (X_train-min_train).max()

# %%
range_train
# Out:
# A16    61654
# A17       10
# A18     8637
# A19     8922
# A20     9014
# A21     9126
# A22     1129
# A23        5
# A24        4
# A25       21
# A26        7
# A27        8
# A28     8664
# A29        7
# A30     1411
# F16    57980
# F17       11
# F18     2990
# F19     3179
# F20     3289
# F21     3418
# F22      744
# F23        4
# F24        3
# F25        6
# F26        2
# F27        3
# F28     3160
# F29        3
# F30      992
# B16    51906
# B17        9
# B18     4678
# B19     4134
# B20     4308
# B21     4465
# B22      488
# B23        4
# B24        3
# B25        6
# B26        4
# B27        4
# B28     4023
# B29        3
# B30      571
# dtype: int64

# %%
X_train_scaled = (X_train-min_train)/range_train

# %%
X_train_scaled
# Out:
#           A16  A17       A18       A19       A20       A21       A22  A23  \
# 81   0.628264  0.5  0.413338  0.375701  0.397493  0.413763  0.318866  0.8
# 31   0.650777  0.3  0.333912  0.293096  0.304304  0.308131  0.219663  0.6
# 42   0.627226  0.6  0.681371  0.658597  0.663412  0.668201  0.319752  0.6
# 59   0.914199  0.9  0.358574  0.355077  0.368649  0.381438  0.230292  0.8
# 26   0.628410  0.6  0.633785  0.618135  0.626359  0.631164  0.291408  0.6
# ..        ...  ...       ...       ...       ...       ...       ...  ...
# 61   0.910598  0.7  0.811740  0.792311  0.804748  0.813062  0.491585  0.6
# 15   0.928666  0.9  0.737640  0.699955  0.706789  0.711374  0.186891  0.6
# 116  0.937376  0.8  0.418317  0.340619  0.356002  0.365111  0.249779  0.8
# 12   0.764508  0.6  0.750724  0.725062  0.729865  0.724414  0.419841  0.4
# 98   0.791563  0.8  0.324302  0.295337  0.302529  0.306049  0.565988  0.4
#
#       A24       A25  ...       B21       B22   B23       B24       B25   B26  \
# ...

# %%
#sns.scatterplot(x= X_train['Anim Fixation Time [ms]'], y= X_train['Anim Net Dwell Time [ms]'],hue= y_train)

# %%
#sns.scatterplot(x= X_train_scaled['Anim Fixation Time [ms]'], y= X_train_scaled['Anim Net Dwell Time [ms]'],hue= y_train)

# %%
min_test = X_test.min()

# %%
range_test = (X_test - min_test).max()

# %%
X_test_scaled = (X_test - min_test)/range_test

# %%
X_test_scaled
# Out:
#           A16       A17       A18       A19       A20       A21       A22  \
# 33   0.532394  0.333333  0.321731  0.323715  0.334467  0.340210  0.137831
# 30   0.583218  0.333333  0.244645  0.415368  0.419840  0.424798  0.103614
# 18   0.542361  0.333333  0.541611  0.615810  0.623395  0.629448  0.271325
# 67   0.912402  0.333333  0.682619  0.666667  0.672007  0.677690  0.077108
# 55   0.840018  0.222222  0.449130  0.389165  0.407440  0.414102  0.027470
# 113  0.930756  0.666667  0.172133  0.145384  0.153846  0.162737  0.107952
# 75   0.936179  1.000000  0.590473  0.565616  0.573247  0.588081  0.145542
# 10   0.731696  0.555556  0.727242  0.645550  0.651267  0.655315  0.140241
# 2    1.000000  0.666667  0.244980  0.234936  0.236036  0.239686  0.067952
# 74   0.162353  0.222222  0.236502  0.217910  0.217821  0.221022  0.166747
# 63   0.958792  0.555556  0.421129  0.427750  0.437617  0.447173  0.142651
# 5    0.430262  0.000000  0.000000  0.000000  0.000000  0.000000  0.043855
# ...

# %%
from sklearn.svm import SVC 
from sklearn.metrics import classification_report, confusion_matrix

svc_model = SVC()
svc_model.fit(X_train_scaled, y_train)
# Out:
# SVC()

# %%
y_predict = svc_model.predict(X_test_scaled)
cm = confusion_matrix(y_test, y_predict)

# %%
sns.heatmap(cm, annot=True, fmt="d")
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#           NG       0.87      0.72      0.79        18
#          OSB       0.76      0.89      0.82        18
#
#     accuracy                           0.81        36
#    macro avg       0.81      0.81      0.80        36
# weighted avg       0.81      0.81      0.80        36

# %% [markdown]
# # K-FOLD CROSS VALIDATION SVM

# %%
# importing cross_val_score function
from sklearn.model_selection import cross_val_score
# 10-fold CV
scores = cross_val_score(svc_model, X_train, y_train, scoring = 'f1', cv=10 )
scores
# Out:
# C:\Users\Mihriban\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Mihriban\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Mihriban\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\Users\Mihriban\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\Users\Mihriban\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Mihriban\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 1071, in f1_score
# ...

# %%
print (np.mean(scores))
# Out:
# nan

# %%
from sklearn.model_selection import cross_val_predict
pred = cross_val_predict (svc_model, X_test, y_test)
pred
# Out:
# array(['OSB', 'OSB', 'OSB', 'OSB', 'OSB', 'NG', 'NG', 'OSB', 'OSB', 'NG',
#        'OSB', 'OSB', 'NG', 'NG', 'OSB', 'NG', 'OSB', 'NG', 'OSB', 'NG',
#        'OSB', 'NG', 'OSB', 'OSB', 'NG', 'OSB', 'OSB', 'NG', 'OSB', 'OSB',
#        'NG', 'NG', 'OSB', 'OSB', 'NG', 'NG'], dtype=object)

# %%
# 10_fold CV on test data
scores_test = cross_val_score(svc_model, X_test, y_test, cv=10)
scores_test
# Out:
# array([0.5       , 0.75      , 0.75      , 0.75      , 0.75      ,
#        0.75      , 0.66666667, 0.66666667, 0.66666667, 0.66666667])

# %%
from sklearn.model_selection import KFold
kfold = KFold (n_splits= 3, shuffle = True, random_state= 0)  
score = cross_val_score(svc_model, X, y,  cv=kfold)
score.mean()
# Out:
# 0.7395299145299146

# %% [markdown]
# # IMPROVING THE MODEL 2

# %%
param_grid = {'C': [0.1, 1, 10, 100], 'gamma' : [1, 0.1, 0.01, 0.001], 'kernel' : ['rbf']}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 4)

# %%
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.529 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.529 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.529 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.562 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.562 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.529 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.529 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.529 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.562 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.562 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.529 total time=   0.0s
# ...

# %%
grid.best_params_
# Out:
# {'C': 1, 'gamma': 1, 'kernel': 'rbf'}

# %%
grid_predict = grid.predict(X_test_scaled)

# %%
cm = confusion_matrix(y_test, grid_predict)

# %%
sns.heatmap(cm, annot= True)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test, grid_predict))
# Out:
#               precision    recall  f1-score   support
#
#           NG       0.89      0.44      0.59        18
#          OSB       0.63      0.94      0.76        18
#
#     accuracy                           0.69        36
#    macro avg       0.76      0.69      0.67        36
# weighted avg       0.76      0.69      0.67        36
